# %%
# MOVIE RATING ANALYTICS ( ADVANCED VISULIZATION )

import pandas as pd
import os

# %%
os.getcwd() # if you want to change the working directory
# Out:
# 'c:\\Users\\DeLL\\Python Data Science Work'

# %%
df = pd.read_csv(r'C:\Users\DeLL\Python Data Science Work\Movie-Rating.csv')

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(df)
# Out:
# 559

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 6

# %%
df.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
df.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
df.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
df.Film = df.Film.astype('category')

# %%
df.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
df.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
df.Genre = df.Genre.astype('category')
df.Year = df.Year.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
df.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
df.Year.cat.categories
# Out:
# Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
df.describe()
# Now we will get only integer value with meaning ful insides
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# How to working with joint plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = df, x = 'CriticRating', y = 'AudienceRating')
plt.show()

# %%
j1 = sns.jointplot( data = df, x = 'CriticRating', y = 'AudienceRating', kind = 'hex')

# %%
plt.show()

# %%
j2 = sns.jointplot(data = df, x = 'CriticRating', y = 'AudienceRating', kind = 'reg')
plt.show()

# %%
m1 = sns.distplot(df.AudienceRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(df.AudienceRating, bins = 15)
plt.show()

# %%
n1 = plt.hist(df.AudienceRating, bins=15)
plt.show()

# %%
sns.set_style('white')
n1 = plt.hist(df.AudienceRating, bins=20)
plt.show()

# %%
n2 = plt.hist(df.CriticRating, bins=20)
plt.show()

# %%
plt.hist(df.BudgetMillions)
plt.show()

# %%
plt.hist(df[df.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
df.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
df.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(df[df.Genre == 'Action'].BudgetMillions, bins = 20, label = 'Action')
plt.hist(df[df.Genre == 'Thriller'].BudgetMillions, bins = 20, label = 'Thriller')
plt.hist(df[df.Genre == 'Drama'].BudgetMillions, bins = 20, label = 'Drama')
plt.ylabel('Number Of Movies')
plt.xlabel('Budget In Million')
plt.legend(title = 'Movie Genre')
plt.show()

# %%
plt.hist([df[df.Genre == 'Action'].BudgetMillions,\
        df[df.Genre == 'Drama'].BudgetMillions,\
        df[df.Genre == 'Thriller'].BudgetMillions,\
        df[df.Genre == 'Comedy'].BudgetMillions],
        bins = 20 , stacked = True)
plt.show()

# %%
for gen in df.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
j = sns.lmplot( data = df, x = 'CriticRating', y = 'AudienceRating',fit_reg=False)
plt.show()

# %%
j = sns.lmplot( data = df, x = 'CriticRating', y = 'AudienceRating',fit_reg=False, hue = 'Genre')
plt.show()

# %%
j = sns.lmplot( data = df, x = 'CriticRating', y = 'AudienceRating',fit_reg=False, hue = 'Genre',aspect = 1)
plt.show()

# %%
# vis1 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating',\
                 #fit_reg=False, hue = 'Genre', size = 10,aspect=1)

# %%
k1 = sns.kdeplot(data = df , x= 'CriticRating', y = 'AudienceRating', fill =True)
plt.show()

# %%
k1 = sns.kdeplot(data = df , x= 'CriticRating', y = 'AudienceRating',shade_lowest=False,cmap='Reds')
plt.show()

# %%
k2 = sns.kdeplot(data = df , x= 'CriticRating', y = 'AudienceRating',shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
k3 = sns.kdeplot(data = df , x= 'BudgetMillions', y = 'AudienceRating',shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
k2 = sns.kdeplot(x = 'BudgetMillions',y = 'CriticRating', data = df)
plt.show()

# %%
f, ax = plt.subplots(1,2, figsize =(12,6))
plt.show()

# %%
ax = plt.subplots(3,3, figsize =(12,6))
plt.show()

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(data = df , x='BudgetMillions',y='AudienceRating',ax = axes[0])
k2 = sns.kdeplot(data = df , x='BudgetMillions',y='CriticRating',ax = axes[1])
plt.show()

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
sns.set_style('dark')
w = sns.boxplot(data=df, x='Genre', y = 'CriticRating')
plt.show()

# %%
z = sns.violinplot(data=df, x='Genre', y = 'CriticRating', palette ='husl') 
plt.show()

# %%
w1 = sns.boxplot(data=df[df.Genre == 'Drama'], x='Year', y = 'CriticRating',palette = 'husl')
plt.show()

# %% [markdown]
# ## Createing a Facet grid

# %%
g = sns.FacetGrid (df, row = 'Genre', col = 'Year', hue = 'Genre') # Kind of Subplots
plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
plt.scatter(df.CriticRating, df.AudienceRating)
plt.show()

# %%
g = sns.FacetGrid (df, row = 'Genre', col = 'Year', hue = 'Genre') 
g = g.map(plt.scatter,'CriticRating', 'AudienceRating')
plt.show()

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions') #scatterplots are mapped in facetgrid
plt.show()

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data = df , x= 'BudgetMillions', y = 'AudienceRating',ax=axes[0,0])
k2 = sns.kdeplot(data = df , x= 'BudgetMillions', y = 'CriticRating',ax=axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=df[df.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(data = df , x= 'CriticRating', y = 'AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(data = df , x= 'AudienceRating', y = 'CriticRating',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
# How can you style your dashboard  using different color map
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(data = df , x= 'BudgetMillions', y = 'AudienceRating', \
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(data = df , x= 'BudgetMillions', y = 'AudienceRating',\
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(data = df , x= 'BudgetMillions', y = 'CriticRating',\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(data = df , x= 'BudgetMillions', y = 'CriticRating',\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=df[df.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data = df , x= 'CriticRating', y = 'AudienceRating', \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(data = df , x= 'CriticRating', y = 'AudienceRating', \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
