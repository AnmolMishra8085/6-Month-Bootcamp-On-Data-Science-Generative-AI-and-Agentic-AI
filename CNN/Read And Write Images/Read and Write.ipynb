# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\DeLL\Pictures\Peacock Image.jpg")

# %%
input
# Out:
# array([[[ 37,  54,  57],
#         [ 37,  54,  57],
#         [ 35,  54,  57],
#         ...,
#         [ 40,  61,  89],
#         [ 44,  64,  95],
#         [ 46,  66,  97]],
#
#        [[ 39,  56,  59],
#         [ 38,  55,  58],
#         [ 36,  55,  58],
#         ...,
#         [ 42,  60,  89],
#         [ 46,  64,  93],
#         [ 48,  66,  97]],
#
#        [[ 41,  58,  61],
#         [ 40,  57,  60],
#         [ 38,  57,  60],
#         ...,
#         [ 44,  63,  90],
#         [ 46,  64,  93],
#         [ 47,  65,  94]],
#
#        ...,
#
#        [[ 28,  59,  52],
#         [ 25,  56,  49],
#         [ 23,  51,  45],
#         ...,
#         [ 40, 107,  70],
#         [ 42, 107,  75],
#         [ 44, 108,  78]],
#
#        [[ 33,  61,  55],
#         [ 30,  58,  52],
#         [ 26,  52,  46],
#         ...,
#         [ 37, 103,  68],
#         [ 37, 101,  71],
#         [ 37, 101,  72]],
#
#        [[ 41,  67,  61],
#         [ 36,  62,  56],
#         [ 31,  54,  49],
# ...

# %%
cv2.imshow("Peacock", input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('Height of Image:', input.shape[0], 'Pixels')
print('Width of Image:', input.shape[1], 'Pixels')
# Out:
# Height of Image: 3174 Pixels
# Width of Image: 5184 Pixels

# %%
# save image in png format
cv2.imwrite(r"Peacock Image.png", input)
