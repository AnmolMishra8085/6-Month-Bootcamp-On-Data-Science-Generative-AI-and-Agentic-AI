# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\DeLL\Python Data Science Work\emp_sal.csv")

# %%
df.head()
# Out:
#                Position  Level  Salary
# 0  Jr Software Engineer      1   45000
# 1  Sr Software Engineer      2   50000
# 2             Team Lead      3   60000
# 3               Manager      4   80000
# 4            Sr manager      5  110000

# %%
df.shape
# Out:
# (10, 3)

# %% [markdown]
# ## Linear Regression

# %%
x = df.iloc[:,1:2].values
y = df.iloc[:, 2].values

from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)

#linear regression visualiztion
plt.scatter(x,y,color = 'red')
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title('Linear Regression Graph')
plt.xlabel("Position Level")
plt.ylabel('Salary')
plt.show()

lin_model_pred = lin_reg.predict([[6.5]])
print (lin_model_pred)
# Out:
# [330378.78787879]

# %% [markdown]
# ## Polynomial Regression

# %%
# Polynomial with degree 2
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=2)
x_poly = poly_reg.fit_transform(x)

poly_reg.fit(x_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)

plt.scatter(x,y,color = 'red')
plt.plot(x,lin_reg_2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title('Truth or Bluff(Polynomial Regression)')
plt.xlabel("Position Level")
plt.ylabel('Salary')
plt.show()

poly_model_pred = lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
print(poly_model_pred)
# Out:
# [189498.10606061]

# %%
# Polynomial with degree 3
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=3)
x_poly = poly_reg.fit_transform(x)

poly_reg.fit(x_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)

plt.scatter(x,y,color = 'red')
plt.plot(x,lin_reg_2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title('Truth or Bluff(Polynomial Regression)')
plt.xlabel("Position Level")
plt.ylabel('Salary')
plt.show()

poly_model_pred = lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
print(poly_model_pred)
# Out:
# [133259.46969697]

# %%
# Polynomial with degree 4
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
x_poly = poly_reg.fit_transform(x)

poly_reg.fit(x_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)

plt.scatter(x,y,color = 'red')
plt.plot(x,lin_reg_2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title('Truth or Bluff(Polynomial Regression)')
plt.xlabel("Position Level")
plt.ylabel('Salary')
plt.show()

poly_model_pred = lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
print(poly_model_pred)
# Out:
# [158862.45265153]

# %%
# Polynomial with degree 5
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=5)
x_poly = poly_reg.fit_transform(x)

poly_reg.fit(x_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)

plt.scatter(x,y,color = 'red')
plt.plot(x,lin_reg_2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title('Truth or Bluff(Polynomial Regression)')
plt.xlabel("Position Level")
plt.ylabel('Salary')
plt.show()

poly_model_pred = lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
print(poly_model_pred)
# Out:
# [174878.07765118]

# %%
# Polynomial with degree 6
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=6)
x_poly = poly_reg.fit_transform(x)

poly_reg.fit(x_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)

plt.scatter(x,y,color = 'red')
plt.plot(x,lin_reg_2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title('Truth or Bluff(Polynomial Regression)')
plt.xlabel("Position Level")
plt.ylabel('Salary')
plt.show()

poly_model_pred = lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
print(poly_model_pred)
# Out:
# [174192.81930584]

# %% [markdown]
# ### Best Fit Of Polynomial Regression is with degree 5 with 174.8 k

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR
svr_model = SVR()
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [130001.82883924]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='rbf',degree=3,gamma='scale', C=1.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [130001.82883924]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='rbf',degree=5,gamma='scale', C=1.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [130001.82883924]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='rbf',degree=5,gamma='auto', C=10.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [130015.57601565]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='sigmoid',degree=5,gamma='auto', C=10.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [129999.99952992]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='sigmoid',degree=5,gamma='scale', C=10.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [129998.44128756]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='sigmoid',degree=5,gamma='scale', C=1.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [129999.84412876]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='sigmoid',degree=3,gamma='auto', C=10.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [129999.99952992]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='poly', degree=4,gamma='scale',C= 10.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [168727.91259234]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='poly', degree=4,gamma='scale',C= 1.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [134160.63306167]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='poly', degree=4,gamma='scale',C= 12.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [168970.22878401]

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='poly', degree=4,gamma='auto',C= 10.0)
svr_model.fit(x,y)

svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [175705.60452113]

# %% [markdown]
# ### Best Fit Of SVR is 175.7 k is with (kernel='poly', degree=4,gamma='auto',C= 10.0)

# %% [markdown]
# ## KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',algorithm='brute',p=2)
knn_model.fit(x,y)

knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [175348.8372093]

# %%
knn_model1 = KNeighborsRegressor(n_neighbors=3, weights='distance', algorithm='brute', p=2)
knn_model1.fit(x, y)
print(knn_model1.predict([[6.5]]))
# Out:
# [192857.14285714]

# %%
knn_model2 = KNeighborsRegressor(n_neighbors=5, weights='uniform', algorithm='brute', p=2)
knn_model2.fit(x, y)
print(knn_model2.predict([[6.5]]))
# Out:
# [168000.]

# %%
knn_model3 = KNeighborsRegressor(n_neighbors=5, weights='distance', algorithm='auto', p=2)
knn_model3.fit(x, y)
print(knn_model3.predict([[6.5]]))
# Out:
# [175348.8372093]

# %%
knn_model4 = KNeighborsRegressor(n_neighbors=7, weights='uniform', algorithm='brute', p=2)
knn_model4.fit(x, y)
print(knn_model4.predict([[6.5]]))
# Out:
# [334285.71428571]

# %%
knn_model5 = KNeighborsRegressor(n_neighbors=10, weights='distance', algorithm='auto', p=2)
knn_model5.fit(x, y)
print(knn_model5.predict([[6.5]]))
# Out:
# [214872.11757064]

# %% [markdown]
# ### Best Fit Of KNN Regression is 175.3 k is with (n_neighbors=5, weights='distance', algorithm='auto', p=2)

# %% [markdown]
# #  TREE ALGORITHEM

# %% [markdown]
# ## Decission tree model

# %%
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor()
dt_model.fit(x,y)

dt_model_pred = dt_model.predict([[6.5]])
print(dt_model_pred)
# Out:
# [150000.]

# %% [markdown]
# ### Result Of Decission Tree is 150 k

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(random_state=0)
rf_model.fit(x,y)

rf_model_pred =  rf_model.predict([[6.5]])
print(rf_model_pred)
# Out:
# [158300.]

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=50,random_state=0)
rf_model.fit(x,y)

rf_model_pred =  rf_model.predict([[6.5]])
print(rf_model_pred)
# Out:
# [161200.]

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=10,random_state=0)
rf_model.fit(x,y)

rf_model_pred =  rf_model.predict([[6.5]])
print(rf_model_pred)
# Out:
# [167000.]

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=32,random_state=0)
rf_model.fit(x,y)

rf_model_pred =  rf_model.predict([[6.5]])
print(rf_model_pred)
# Out:
# [163437.5]

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=70,random_state=0)
rf_model.fit(x,y)

rf_model_pred =  rf_model.predict([[6.5]])
print(rf_model_pred)
# Out:
# [160285.71428571]

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=23,random_state=0)
rf_model.fit(x,y)

rf_model_pred =  rf_model.predict([[6.5]])
print(rf_model_pred)
# Out:
# [168260.86956522]

# %% [markdown]
# ### Best Fit Of Random Forest Regression is 168.2 k
